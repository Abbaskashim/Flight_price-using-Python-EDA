# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('/Users/abbaskashim/Downloads/flight price.csv')

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 0           IndiGo      24-03-2019  Banglore   New Delhi    22:20
# 1        Air India      01-05-2019   Kolkata    Banglore     5:50
# 2      Jet Airways      09-06-2019     Delhi      Cochin     9:25
# 3           IndiGo      12-05-2019   Kolkata    Banglore    18:05
# 4           IndiGo      01-03-2019  Banglore   New Delhi    16:50
# ...            ...             ...       ...         ...      ...
# 10678     Air Asia      09-04-2019   Kolkata    Banglore    19:55
# 10679    Air India      27-04-2019   Kolkata    Banglore    20:45
# 10680  Jet Airways      27-04-2019  Banglore       Delhi     8:20
# 10681      Vistara      01-03-2019  Banglore   New Delhi    11:30
# 10682    Air India      09-05-2019     Delhi      Cochin    10:55
#
#            Arrival_Time Duration Total_Stops Additional_Info  Price
# 0                   NaN   2h 50m    non-stop         No info   3897
# ...

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination Dep_Time  \
# 0       IndiGo      24-03-2019  Banglore   New Delhi    22:20
# 1    Air India      01-05-2019   Kolkata    Banglore     5:50
# 2  Jet Airways      09-06-2019     Delhi      Cochin     9:25
# 3       IndiGo      12-05-2019   Kolkata    Banglore    18:05
# 4       IndiGo      01-03-2019  Banglore   New Delhi    16:50
#
#        Arrival_Time Duration Total_Stops Additional_Info  Price
# 0               NaN   2h 50m    non-stop         No info   3897
# 1             13:15   7h 25m     2 stops         No info   7662
# 2  10-06-2023 04:25      19h     2 stops         No info  13882
# 3             23:30   5h 25m      1 stop         No info   6218
# 4             21:35   4h 45m      1 stop         No info  13302

# %%
df.tail()
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 10678     Air Asia      09-04-2019   Kolkata    Banglore    19:55
# 10679    Air India      27-04-2019   Kolkata    Banglore    20:45
# 10680  Jet Airways      27-04-2019  Banglore       Delhi     8:20
# 10681      Vistara      01-03-2019  Banglore   New Delhi    11:30
# 10682    Air India      09-05-2019     Delhi      Cochin    10:55
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 10678        22:25   2h 30m    non-stop         No info   4107
# 10679        23:20   2h 35m    non-stop         No info   4145
# 10680        11:20       3h    non-stop         No info   7229
# 10681        14:10   2h 40m    non-stop         No info  12648
# 10682        19:15   8h 20m     2 stops         No info  11753

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Dep_Time         10683 non-null  object
#  5   Arrival_Time     10682 non-null  object
#  6   Duration         10683 non-null  object
#  7   Total_Stops      10682 non-null  object
#  8   Additional_Info  10683 non-null  object
#  9   Price            10683 non-null  int64
# dtypes: int64(1), object(9)
# memory usage: 834.7+ KB

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Dep_Time           0
# Arrival_Time       1
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Dep_Time',
#        'Arrival_Time', 'Duration', 'Total_Stops', 'Additional_Info', 'Price'],
#       dtype='object')

# %%
df['Arrival_Time'].unique()
# Out:
# array([nan, '13:15', '10-06-2023 04:25', ..., '10-03-2023 06:50',
#        '19-03-2023 00:05', '13-03-2023 21:20'], dtype=object)

# %%
df['Arrival_Time'].fillna('01:10',inplace=True)

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
df[df['Total_Stops'].isnull()]
# Out:
#         Airline Date_of_Journey Source Destination Dep_Time      Arrival_Time  \
# 9039  Air India      06-05-2019  Delhi      Cochin     9:45  07-05-2023 09:25
#
#      Duration Total_Stops Additional_Info  Price
# 9039  23h 40m         NaN         No info   7480

# %%
df['Arrival_Time']=df['Arrival_Time'].str.replace('2023','2019')

# %%
df.Arrival_Time
# Out:
# 0                   01:10
# 1                   13:15
# 2        10-06-2019 04:25
# 3                   23:30
# 4                   21:35
#                ...
# 10678               22:25
# 10679               23:20
# 10680               11:20
# 10681               14:10
# 10682               19:15
# Name: Arrival_Time, Length: 10683, dtype: object

# %%
df[df['Arrival_Time'].str.contains('2019')]
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 2      Jet Airways      09-06-2019     Delhi      Cochin     9:25
# 6      Jet Airways      12-03-2019  Banglore   New Delhi    18:55
# 7      Jet Airways      01-03-2019  Banglore   New Delhi     8:00
# 8      Jet Airways      12-03-2019  Banglore   New Delhi     8:55
# 13     Jet Airways      09-05-2019   Kolkata    Banglore    21:10
# ...            ...             ...       ...         ...      ...
# 10666  Jet Airways      12-06-2019     Delhi      Cochin    18:15
# 10667  Jet Airways      12-03-2019  Banglore   New Delhi    22:55
# 10672  Jet Airways      27-06-2019     Delhi      Cochin    23:05
# 10673  Jet Airways      27-05-2019     Delhi      Cochin    13:25
# 10674  Jet Airways      12-03-2019  Banglore   New Delhi    20:35
#
#            Arrival_Time Duration Total_Stops              Additional_Info  \
# 2      10-06-2019 04:25      19h     2 stops                      No info
# ...

# %%
df['Total_Stops'].fillna('1 stop',inplace=True)

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %%
a= df.groupby(['Airline'], as_index=False)['Price'].sum().sort_values(by='Price',ascending=False)
a
# Out:
#                               Airline     Price
# 4                         Jet Airways  44817461
# 1                           Air India  16838841
# 6                   Multiple carriers  13039603
# 3                              IndiGo  11648071
# 10                            Vistara   3734451
# 8                            SpiceJet   3548717
# 0                            Air Asia   1783293
# 2                               GoAir   1137045
# 5                Jet Airways Business    350152
# 7   Multiple carriers Premium economy    148445
# 11            Vistara Premium economy     26887
# 9                              Trujet      4140

# %%
plt.figure(figsize=(15, 10))
x=sns.barplot(x='Airline', y='Price' , data=a)
for bars in x.containers:
    x.bar_label(bars, fmt='%.2f')

plt.title('Total Price by Airline')
plt.xlabel('Airline')
plt.ylabel('Total Price')
plt.xticks(rotation=90)
plt.show()
